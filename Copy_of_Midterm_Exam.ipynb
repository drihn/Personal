# %% [markdown]
# <a href="https://colab.research.google.com/github/drihn/Personal/blob/main/Copy_of_Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LogisticRegression # import the LogisticRegression class
from sklearn.metrics import mean_squared_error, r2_score

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXERCISES/blob/f5fdfba1aabbbafcf2fe49ca6e1c8f92f69d1458/datasets/titanic/train.csv?raw=true'
df = pd.read_csv(dataset_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 716          717         1       1
# 177          178         0       1
# 268          269         1       1
# 339          340         0       1
# 504          505         1       1
# 377          378         0       1
# 297          298         0       1
# 449          450         1       1
# 779          780         1       1
# 118          119         0       1
# 273          274         0       1
# 390          391         1       1
# 445          446         1       1
# 473          474         1       2
# 245          246         0       1
# 699          700         0       3
# 802          803         1       1
# 539          540         1       1
# 505          506         0       1
# 251          252         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
label_encoder = LabelEncoder()
df['Name'] = label_encoder.fit_transform(df['Name'])
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['Age'] = label_encoder.fit_transform(df['Age'])
df['SibSp'] = label_encoder.fit_transform(df['SibSp'])
df['Parch'] = label_encoder.fit_transform(df['Parch'])
df['Ticket'] = label_encoder.fit_transform(df['Ticket'])
df['Fare'] = label_encoder.fit_transform(df['Fare'])
df['Cabin'] = label_encoder.fit_transform(df['Cabin'])
df['Embarked'] = label_encoder.fit_transform(df['Embarked'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# 1              2         1       1    49    0   32      1      0     109
# 3              4         1       1    70    0   28      1      0      31
# 6              7         0       1   112    1   49      0      0      55
# 10            11         1       3   148    0    4      1      1     120
# 11            12         1       1    27    0   53      0      0      26
# ..           ...       ...     ...   ...  ...  ...    ...    ...     ...
# 871          872         1       1    18    0   42      1      1      33
# 872          873         0       1    35    1   26      0      0      89
# 879          880         1       1   140    0   51      0      1      38
# 887          888         1       1    75    0   12      0      0      10
# 889          890         1       1    20    1   18      0      0       8
#
#      Fare  Cabin  Embarked
# 1      57     72         0
# 3      44     48         2
# ...

# %%
y = df['Survived']
y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: Survived, Length: 183, dtype: int64

# %%
x = df.drop(['Survived'],axis=1)
x
# Out:
#      PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# 1              2       1    49    0   32      1      0     109    57     72
# 3              4       1    70    0   28      1      0      31    44     48
# 6              7       1   112    1   49      0      0      55    41    117
# 10            11       3   148    0    4      1      1     120    10    131
# 11            12       1    27    0   53      0      0      26    17     43
# ..           ...     ...   ...  ...  ...    ...    ...     ...   ...    ...
# 871          872       1    18    0   42      1      1      33    43     91
# 872          873       1    35    1   26      0      0      89     1     29
# 879          880       1   140    0   51      0      1      38    68     61
# 887          888       1    75    0   12      0      0      10    23     25
# 889          890       1    20    1   18      0      0       8    23     52
#
#      Embarked
# 1           0
# 3           2
# ...

# %% [markdown]
# 1. Use the Dataset file to train your model. Split this into train and test to calculate the RMSE

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y_scaled, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 0.5452497568062706

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXERCISES/blob/f5fdfba1aabbbafcf2fe49ca6e1c8f92f69d1458/datasets/titanic/test.csv?raw=true'
dt=pd.read_csv(test_url)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
dt.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dt.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
dt.sample(20)
# Out:
#      PassengerId  Pclass                                               Name  \
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 167         1059       3                            Ford, Mr. Edward Watson
# 209         1101       3                                 Delalic, Mr. Redjo
# 369         1261       2                      Pallas y Castello, Mr. Emilio
# 298         1190       1                         Loring, Mr. Joseph Holland
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 191         1083       1                             Salomon, Mr. Abraham L
# 180         1072       2                          McCrie, Mr. James Matthew
# 145         1037       3                          Vander Planke, Mr. Julius
# 252         1144       1                           Clark, Mr. Walter Miller
# 255         1147       3                         MacKay, Mr. George William
# ...

# %%
label_encoder = LabelEncoder()
# Use dt instead of df in fit_transform
dt['Name'] = label_encoder.fit_transform(dt['Name'])
dt['Sex'] = label_encoder.fit_transform(dt['Sex'])
dt['Age'] = label_encoder.fit_transform(dt['Age'])
dt['SibSp'] = label_encoder.fit_transform(dt['SibSp'])
dt['Parch'] = label_encoder.fit_transform(dt['Parch'])
dt['Ticket'] = label_encoder.fit_transform(dt['Ticket'])
dt['Fare'] = label_encoder.fit_transform(dt['Fare'])
dt['Cabin'] = label_encoder.fit_transform(dt['Cabin'])
dt['Embarked'] = label_encoder.fit_transform(dt['Embarked'])

# %%
sample_submission_url ='https://github.com/robitussin/CCMACLRL_EXERCISES/blob/f5fdfba1aabbbafcf2fe49ca6e1c8f92f69d1458/datasets/titanic/gender_submission.csv?raw=true'

sf=pd.read_csv(sample_submission_url)

# %%
id = sf.pop('PassengerId')
y_pred = model.predict(dt)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'PassengerID': id,
    'Survived': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    int64
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    int64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    int64
#  8   Fare         418 non-null    int64
#  9   Cabin        418 non-null    int64
#  10  Embarked     418 non-null    int64
# dtypes: int64(11)
# memory usage: 36.0 KB
